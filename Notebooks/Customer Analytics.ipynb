# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import pickle

# %%
df_segmentation = pd.read_csv('../Datasets/segmentation data.csv', index_col=0)

# %%
df_segmentation.head()
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
#
#            Settlement size
# ID
# 100000001                2
# 100000002                2
# 100000003                0
# 100000004                1
# 100000005                1

# %%
df_segmentation.describe()
# Out:
#                Sex  Marital status          Age   Education         Income  \
# count  2000.000000     2000.000000  2000.000000  2000.00000    2000.000000
# mean      0.457000        0.496500    35.909000     1.03800  120954.419000
# std       0.498272        0.500113    11.719402     0.59978   38108.824679
# min       0.000000        0.000000    18.000000     0.00000   35832.000000
# 25%       0.000000        0.000000    27.000000     1.00000   97663.250000
# 50%       0.000000        0.000000    33.000000     1.00000  115548.500000
# 75%       1.000000        1.000000    42.000000     1.00000  138072.250000
# max       1.000000        1.000000    76.000000     3.00000  309364.000000
#
#         Occupation  Settlement size
# count  2000.000000      2000.000000
# mean      0.810500         0.739000
# std       0.638587         0.812533
# min       0.000000         0.000000
# 25%       0.000000         0.000000
# 50%       1.000000         1.000000
# 75%       1.000000         1.000000
# max       2.000000         2.000000

# %%
df_segmentation.corr()
# Out:
#                       Sex  Marital status       Age  Education    Income  \
# Sex              1.000000        0.566511 -0.182885   0.244838 -0.195146
# Marital status   0.566511        1.000000 -0.213178   0.374017 -0.073528
# Age             -0.182885       -0.213178  1.000000   0.654605  0.340610
# Education        0.244838        0.374017  0.654605   1.000000  0.233459
# Income          -0.195146       -0.073528  0.340610   0.233459  1.000000
# Occupation      -0.202491       -0.029490  0.108388   0.064524  0.680357
# Settlement size -0.300803       -0.097041  0.119751   0.034732  0.490881
#
#                  Occupation  Settlement size
# Sex               -0.202491        -0.300803
# Marital status    -0.029490        -0.097041
# Age                0.108388         0.119751
# Education          0.064524         0.034732
# Income             0.680357         0.490881
# Occupation         1.000000         0.571795
# Settlement size    0.571795         1.000000

# %%
plt.figure(figsize=(8, 6))
s = sns.heatmap(df_segmentation.corr(), 
                annot=True,
                cmap='RdBu',
                vmin = -1,
                vmax = 1)
s.set_yticklabels(s.get_yticklabels(), rotation=0, fontsize=12)
s.set_xticklabels(s.get_xticklabels(), rotation=90, fontsize=12)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
plt.figure(figsize=(12, 9))
plt.scatter(df_segmentation.iloc[:, 2], df_segmentation.iloc[:, 4])
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Visualization of Raw Data')
# Out:
# Text(0.5, 1.0, 'Visualization of Raw Data')

# %%
scaler = StandardScaler()
segmentation_std = scaler.fit_transform(df_segmentation)

# %%
hier_clust = linkage(segmentation_std, method='ward')

# %%
plt.figure(figsize=(12, 9))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Distance')
dendrogram(hier_clust,
           truncate_mode='level',
           p = 5,
           show_leaf_counts=True,
           no_labels=True)
# Out:
# {'icoord': [[5.0, 5.0, 15.0, 15.0],
#   [25.0, 25.0, 35.0, 35.0],
#   [10.0, 10.0, 30.0, 30.0],
#   [45.0, 45.0, 55.0, 55.0],
#   [65.0, 65.0, 75.0, 75.0],
#   [50.0, 50.0, 70.0, 70.0],
#   [20.0, 20.0, 60.0, 60.0],
#   [85.0, 85.0, 95.0, 95.0],
#   [105.0, 105.0, 115.0, 115.0],
#   [90.0, 90.0, 110.0, 110.0],
#   [125.0, 125.0, 135.0, 135.0],
#   [145.0, 145.0, 155.0, 155.0],
#   [130.0, 130.0, 150.0, 150.0],
#   [100.0, 100.0, 140.0, 140.0],
#   [40.0, 40.0, 120.0, 120.0],
#   [165.0, 165.0, 175.0, 175.0],
#   [185.0, 185.0, 195.0, 195.0],
#   [170.0, 170.0, 190.0, 190.0],
#   [205.0, 205.0, 215.0, 215.0],
#   [225.0, 225.0, 235.0, 235.0],
#   [210.0, 210.0, 230.0, 230.0],
#   [180.0, 180.0, 220.0, 220.0],
#   [245.0, 245.0, 255.0, 255.0],
#   [265.0, 265.0, 275.0, 275.0],
#   [250.0, 250.0, 270.0, 270.0],
#   [285.0, 285.0, 295.0, 295.0],
#   [305.0, 305.0, 315.0, 315.0],
#   [290.0, 290.0, 310.0, 310.0],
#   [260.0, 260.0, 300.0, 300.0],
#   [200.0, 200.0, 280.0, 280.0],
#   [80.0, 80.0, 240.0, 240.0],
#   [325.0, 325.0, 335.0, 335.0],
#   [345.0, 345.0, 355.0, 355.0],
#   [330.0, 330.0, 350.0, 350.0],
#   [365.0, 365.0, 375.0, 375.0],
#   [385.0, 385.0, 395.0, 395.0],
#   [370.0, 370.0, 390.0, 390.0],
#   [340.0, 340.0, 380.0, 380.0],
#   [405.0, 405.0, 415.0, 415.0],
#   [425.0, 425.0, 435.0, 435.0],
#   [410.0, 410.0, 430.0, 430.0],
#   [445.0, 445.0, 455.0, 455.0],
#   [465.0, 465.0, 475.0, 475.0],
#   [450.0, 450.0, 470.0, 470.0],
#   [420.0, 420.0, 460.0, 460.0],
#   [360.0, 360.0, 440.0, 440.0],
#   [485.0, 485.0, 495.0, 495.0],
#   [505.0, 505.0, 515.0, 515.0],
#   [490.0, 490.0, 510.0, 510.0],
#   [525.0, 525.0, 535.0, 535.0],
#   [545.0, 545.0, 555.0, 555.0],
#   [530.0, 530.0, 550.0, 550.0],
#   [500.0, 500.0, 540.0, 540.0],
#   [565.0, 565.0, 575.0, 575.0],
#   [585.0, 585.0, 595.0, 595.0],
#   [570.0, 570.0, 590.0, 590.0],
#   [605.0, 605.0, 615.0, 615.0],
#   [625.0, 625.0, 635.0, 635.0],
#   [610.0, 610.0, 630.0, 630.0],
#   [580.0, 580.0, 620.0, 620.0],
#   [520.0, 520.0, 600.0, 600.0],
#   [400.0, 400.0, 560.0, 560.0],
#   [160.0, 160.0, 480.0, 480.0]],
#  'dcoord': [[0.0, 2.1223540150144173, 2.1223540150144173, 0.0],
#   [0.0, 4.3155745482676915, 4.3155745482676915, 0.0],
#   [2.1223540150144173,
#    5.589695377405012,
#    5.589695377405012,
#    4.3155745482676915],
#   [0.0, 6.791198451937796, 6.791198451937796, 0.0],
#   [0.0, 7.803972378606145, 7.803972378606145, 0.0],
#   [6.791198451937796,
#    12.047948567816455,
#    12.047948567816455,
#    7.803972378606145],
#   [5.589695377405012,
#    14.091240220841797,
#    14.091240220841797,
#    12.047948567816455],
#   [0.0, 5.326338957512825, 5.326338957512825, 0.0],
#   [0.0, 8.413061089449444, 8.413061089449444, 0.0],
#   [5.326338957512825, 14.04107999544911, 14.04107999544911, 8.413061089449444],
#   [8.45013452100761,
#    16.760620468263898,
#    16.760620468263898,
#    14.04107999544911],
#   [0.0, 4.532363113975979, 4.532363113975979, 0.0],
#   [0.0, 9.83116762656914, 9.83116762656914, 0.0],
#   [4.532363113975979,
#    12.292237821984994,
#    12.292237821984994,
#    9.83116762656914],
#   [0.0, 6.729198790405168, 6.729198790405168, 0.0],
#   [0.0, 11.565541418045406, 11.565541418045406, 0.0],
#   [6.729198790405168,
#    18.204501006713418,
#    18.204501006713418,
#    11.565541418045406],
#   [12.292237821984994,
#    24.406924804054864,
#    24.406924804054864,
#    18.204501006713418],
#   [16.760620468263898,
#    32.36297994757603,
#    32.36297994757603,
#    24.406924804054864],
#   [25.719802545357478,
#    63.06917547917128,
#    63.06917547917128,
#    32.36297994757603],
#   [56.73375166963763,
#    77.34958547428063,
#    77.34958547428063,
#    63.06917547917128]],
#  'ivl': ['(2)',
#   '(5)',
#   '(8)',
#   '(35)',
#   '(11)',
#   '(16)',
#   '(38)',
#   '(38)',
#   '(21)',
#   '(10)',
#   '(67)',
#   '(60)',
#   '(25)',
#   '(20)',
#   '(113)',
#   '(62)',
#   '(12)',
#   '(41)',
#   '(32)',
#   '(75)',
#   '(12)',
#   '(54)',
#   '(61)',
#   '(42)',
#   '(15)',
#   '(36)',
#   '(18)',
#   '(22)',
#   '(9)',
#   '(32)',
#   '(49)',
#   '(139)',
#   '(5)',
#   '(5)',
#   '(7)',
#   '(9)',
#   '(25)',
#   '(11)',
#   '(22)',
#   '(20)',
#   '(5)',
#   '(10)',
#   '(19)',
#   '(16)',
#   '(11)',
#   '(10)',
#   '(16)',
#   '(50)',
#   '(16)',
#   '(21)',
#   '(21)',
#   '(37)',
#   '(20)',
#   '(40)',
#   '(16)',
#   '(18)',
#   '(20)',
#   '(43)',
#   '(22)',
#   '(107)',
#   '(45)',
#   '(50)',
#   '(36)',
#   '(67)'],
#  'leaves': [3402,
#   3699,
#   3734,
#   3869,
#   3864,
#   3879,
#   3890,
#   3929,
#   3697,
#   3712,
#   3833,
#   3859,
#   3919,
#   3923,
#   3917,
#   3936,
#   3873,
#   3924,
#   3945,
#   3952,
#   3839,
#   3850,
#   3846,
#   3925,
#   3871,
#   3874,
#   3921,
#   3956,
#   3606,
#   3841,
#   3854,
#   3950,
#   3589,
#   3842,
#   3834,
#   3880,
#   3933,
#   3941,
#   3896,
#   3912,
#   3855,
#   3915,
#   3928,
#   3947,
#   3899,
#   3910,
#   3931,
#   3954,
#   3732,
#   3794,
#   3823,
#   3832,
#   3789,
#   3901,
#   3905,
#   3926,
#   3845,
#   3904,
#   3894,
#   3960,
#   3906,
#   3920,
#   3943,
#   3955],
#  'color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C0',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C0',
#   'C0'],
#  'leaves_color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C4']}

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(segmentation_std)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,11), wcss, marker='o', linestyle='--')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('K-means Clustering')
# Out:
# Text(0.5, 1.0, 'K-means Clustering')

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=42)
kmeans.fit(segmentation_std)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
df_segm_kmeans = df_segmentation.copy()
df_segm_kmeans['Segment K-means'] = kmeans.labels_
df_segm_kmeans.head()
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
#
#            Settlement size  Segment K-means
# ID
# 100000001                2                3
# 100000002                2                2
# 100000003                0                0
# 100000004                1                3
# 100000005                1                3

# %%
df_segm_analysis = df_segm_kmeans.groupby(['Segment K-means']).mean()
df_segm_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.066543        0.000000  33.240296   0.489834
# 1                0.868254        0.785714  32.928571   1.163492
# 2                0.691099        0.979058  29.060209   1.104712
# 3                0.149888        0.277405  49.192394   1.467562
#
#                         Income  Occupation  Settlement size
# Segment K-means
# 0                109932.785582    0.639556         0.611830
# 1                 98466.955556    0.384127         0.006349
# 2                126838.926702    1.107330         1.324607
# 3                160958.722595    1.364653         1.425056

# %%
df_segm_analysis['N Obs'] = df_segm_kmeans[['Segment K-means', 'Sex']].groupby(['Segment K-means']).count()

# %%
df_segm_analysis.head()
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.066543        0.000000  33.240296   0.489834
# 1                0.868254        0.785714  32.928571   1.163492
# 2                0.691099        0.979058  29.060209   1.104712
# 3                0.149888        0.277405  49.192394   1.467562
#
#                         Income  Occupation  Settlement size  N Obs
# Segment K-means
# 0                109932.785582    0.639556         0.611830    541
# 1                 98466.955556    0.384127         0.006349    630
# 2                126838.926702    1.107330         1.324607    382
# 3                160958.722595    1.364653         1.425056    447

# %%
df_segm_analysis.rename({0:'well-off', 1:'fewer-opportunities', 2:'standard', 3:'career focused'})
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means
# well-off             0.066543        0.000000  33.240296   0.489834
# fewer-opportunities  0.868254        0.785714  32.928571   1.163492
# standard             0.691099        0.979058  29.060209   1.104712
# career focused       0.149888        0.277405  49.192394   1.467562
#
#                             Income  Occupation  Settlement size  N Obs
# Segment K-means
# well-off             109932.785582    0.639556         0.611830    541
# fewer-opportunities   98466.955556    0.384127         0.006349    630
# standard             126838.926702    1.107330         1.324607    382
# career focused       160958.722595    1.364653         1.425056    447

# %%
df_segm_kmeans['Labels'] = df_segm_kmeans['Segment K-means'].map({0:'well-off', 1:'fewer-opportunities', 2:'standard', 3:'career focused'})

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=df_segm_kmeans, 
    x=df_segm_kmeans['Age'], 
    y=df_segm_kmeans['Income'],
    hue='Labels', 
    palette=['g', 'r', 'c', 'm']  
)

plt.title('Segmentation K-means')
plt.show()

# %%
pca = PCA()

# %%
pca.fit(segmentation_std)
# Out:
# PCA()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.35696328, 0.26250923, 0.18821114, 0.0755775 , 0.05716512,
#        0.03954794, 0.02002579])

# %%
plt.figure(figsize=(12,9))
plt.plot(range(1,8), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.title("Explained Variance by Components")
plt.xlabel("Number of Component")
plt.ylabel("Cumulative Explained Variance")
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
pca = PCA(n_components=3)

# %%
pca.fit(segmentation_std)
# Out:
# PCA(n_components=3)

# %%
pd.DataFrame(data = pca.components_, columns = df_segmentation.columns.values)
# Out:
#         Sex  Marital status       Age  Education    Income  Occupation  \
# 0 -0.314695       -0.191704  0.326100   0.156841  0.524525    0.492059
# 1  0.458006        0.512635  0.312208   0.639807  0.124683    0.014658
# 2 -0.293013       -0.441977  0.609544   0.275605 -0.165662   -0.395505
#
#    Settlement size
# 0         0.464789
# 1        -0.069632
# 2        -0.295685

# %%
df_pca_comp = pd.DataFrame(data=pca.components_, columns=df_segmentation.columns.values, index=['Component 1', 'Component 2', 'Component 3'])

# %%
df_pca_comp.head()
# Out:
#                   Sex  Marital status       Age  Education    Income  \
# Component 1 -0.314695       -0.191704  0.326100   0.156841  0.524525
# Component 2  0.458006        0.512635  0.312208   0.639807  0.124683
# Component 3 -0.293013       -0.441977  0.609544   0.275605 -0.165662
#
#              Occupation  Settlement size
# Component 1    0.492059         0.464789
# Component 2    0.014658        -0.069632
# Component 3   -0.395505        -0.295685

# %%
sns.heatmap(df_pca_comp,
            vmin=-1,
            vmax=1,
            cmap='RdBu',
            annot=True)
plt.yticks([0,1,2], ['Component 1', 'Component 2', 'Component 3'], rotation=45)
# Out:
# ([<matplotlib.axis.YTick at 0x7ee89901aad0>,
#   <matplotlib.axis.YTick at 0x7ee899071bd0>,
#   <matplotlib.axis.YTick at 0x7ee899083750>],
#  [Text(0, 0, 'Component 1'),
#   Text(0, 1, 'Component 2'),
#   Text(0, 2, 'Component 3')])

# %%
scores_pca = pca.transform(segmentation_std)

# %%
wcss = []
for i in range(1, 11):
    kmeans_pca = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,11), wcss, marker='o', linestyle='--')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('K-means with PCA Clustering')
# Out:
# Text(0.5, 1.0, 'K-means with PCA Clustering')

# %%
kmeans_pca = KMeans(n_clusters=4, init='k-means++', random_state=42)
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
df_segm_pca_kmeans = pd.concat([df_segmentation.reset_index(drop=True), pd.DataFrame(scores_pca)], axis=1)

# %%
df_segm_pca_kmeans.head()
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1
#
#           0         1         2
# 0  2.514746  0.834122  2.174806
# 1  0.344935  0.598146 -2.211603
# 2 -0.651063 -0.680093  2.280419
# 3  1.714316 -0.579927  0.730731
# 4  1.626745 -0.440496  1.244909

# %%
df_segm_pca_kmeans.columns.values[-3:] = ['Component 1', 'Component 2', 'Component 3']
df_segm_pca_kmeans['Segment K-means PCA'] = kmeans_pca.labels_

# %%
df_segm_pca_kmeans.head()
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1
#
#    Component 1  Component 2  Component 3  Segment K-means PCA
# 0     2.514746     0.834122     2.174806                    3
# 1     0.344935     0.598146    -2.211603                    2
# 2    -0.651063    -0.680093     2.280419                    1
# 3     1.714316    -0.579927     0.730731                    0
# 4     1.626745    -0.440496     1.244909                    0

# %%
df_segm_pca_kmeans_freq = df_segm_pca_kmeans.groupby(['Segment K-means PCA']).mean()

# %%
df_segm_pca_kmeans_freq.head()
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# 0                    0.001661        0.041528  36.674419   0.684385
# 1                    0.627869        0.454098  33.473770   0.944262
# 2                    0.762357        0.973384  27.889734   1.007605
# 3                    0.492366        0.683206  55.919847   2.129771
#
#                             Income  Occupation  Settlement size  Component 1  \
# Segment K-means PCA
# 0                    138482.186047    1.200997         1.255814     1.228891
# 1                     88824.154098    0.078689         0.009836    -1.607567
# 2                    119503.418251    1.055133         0.813688    -0.395592
# 3                    158400.877863    1.125954         1.099237     1.713376
#
#                      Component 2  Component 3
# Segment K-means PCA
# 0                      -1.220013     0.041063
# 1                      -0.110732     0.625678
# 2                       0.518043    -1.204763
# 3                       2.021006     0.867641

# %%
df_segm_pca_kmeans_freq['N Obs'] = df_segm_pca_kmeans[['Segment K-means PCA', 'Sex']].groupby(['Segment K-means PCA']).count()
df_segm_pca_kmeans_freq['Prop Obs'] = df_segm_pca_kmeans_freq['N Obs']/df_segm_pca_kmeans_freq['N Obs'].sum()
df_segm_pca_kmeans_freq = df_segm_pca_kmeans_freq.rename({0:'standard', 1:'career focused', 2:'fewer opportunities', 3:'well-off'})

# %%
df_segm_pca_kmeans_freq.head()
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# standard             0.001661        0.041528  36.674419   0.684385
# career focused       0.627869        0.454098  33.473770   0.944262
# fewer opportunities  0.762357        0.973384  27.889734   1.007605
# well-off             0.492366        0.683206  55.919847   2.129771
#
#                             Income  Occupation  Settlement size  Component 1  \
# Segment K-means PCA
# standard             138482.186047    1.200997         1.255814     1.228891
# career focused        88824.154098    0.078689         0.009836    -1.607567
# fewer opportunities  119503.418251    1.055133         0.813688    -0.395592
# well-off             158400.877863    1.125954         1.099237     1.713376
#
#                      Component 2  Component 3  N Obs  Prop Obs
# Segment K-means PCA
# standard               -1.220013     0.041063    602     0.301
# career focused         -0.110732     0.625678    610     0.305
# fewer opportunities     0.518043    -1.204763    526     0.263
# well-off                2.021006     0.867641    262     0.131

# %%
df_segm_pca_kmeans['Legend'] = df_segm_pca_kmeans['Segment K-means PCA'].map({0:'standard',
                                                                                   1:'career focused',
                                                                                   2:'fewer opportunities',
                                                                                   3:'well-off'})

# %%
df_segm_pca_kmeans.head()
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1
#
#    Component 1  Component 2  Component 3  Segment K-means PCA  \
# 0     2.514746     0.834122     2.174806                    3
# 1     0.344935     0.598146    -2.211603                    2
# 2    -0.651063    -0.680093     2.280419                    1
# 3     1.714316    -0.579927     0.730731                    0
# 4     1.626745    -0.440496     1.244909                    0
#
#                 Legend
# 0             well-off
# 1  fewer opportunities
# 2       career focused
# 3             standard
# 4             standard

# %%
x_axis = df_segm_pca_kmeans['Component 2']
y_axis = df_segm_pca_kmeans['Component 1']
plt.figure(figsize=(10,8))
sns.scatterplot(x=x_axis, y=y_axis, hue=df_segm_pca_kmeans['Legend'], palette=['g','r', 'c', 'm'])
plt.title('Clustering by PCA')
# Out:
# Text(0.5, 1.0, 'Clustering by PCA')

# %%
pickle.dump(scaler, open('scaler.pkl', 'wb'))
pickle.dump(pca, open('pca.pkl', 'wb'))
pickle.dump(kmeans_pca, open('kmeans_pca.pkl', 'wb'))
